# %%
import os
import time
import importlib
import json
from collections import OrderedDict
import logging
import argparse
import numpy as np
import random
import time
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.optim
import torch.utils.data
import torch.backends.cudnn
import torchvision.utils
import torch.nn.functional as F
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix

import torchvision.transforms as transforms
import torchvision

# %%
class block(nn.Module):
  def __init__(self, in_channels, out_channels, stride = 1, convert = None):
    super(block, self).__init__()
    self.conv1 = nn.Conv2d(in_channels, in_channels, kernel_size=1, stride=stride, padding=0, bias=False)
    self.bn1 = nn.BatchNorm2d(in_channels)
    self.conv2 = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(in_channels)
    self.conv3 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0, bias=False)
    self.bn3 = nn.BatchNorm2d(out_channels)

    self.relu = nn.ReLU(inplace=True)
    self.convert = convert

  def forward(self, x):
    y = x.clone()
    out = self.conv1(x)
    out = self.bn1(out)
    out = self.relu(out)
    out = self.conv2(out)
    out = self.bn2(out)
    out = self.relu(out)
    out = self.conv3(out)
    out = self.bn3(out)

    if self.convert:
      y = self.convert(y)

    out = out + y
    return out

# %%
class ResNet(nn.Module):
  def __init__(self, block, layers, classes = 10):
    super(ResNet, self).__init__()
    self.conv = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn = nn.BatchNorm2d(16)
    self.relu = nn.ReLU(inplace=True)
    self.in_channel = 16

    self.layer1 = self.make_layer(block, 16, layers[0])
    self.layer2 = self.make_layer(block, 32, layers[1], 2)
    self.layer3 = self.make_layer(block, 64, layers[2], 2)
    
    self.avg_pool = nn.AvgPool2d(8)
    self.fc = nn.Linear(64, classes)

  def make_layer(self, block, out_channel, num_layers, stride = 1):
    layer = []
    conv = None
    if stride != 1 or self.in_channel != out_channel:
      conv = nn.Sequential(
          nn.Conv2d(self.in_channel, 
                    out_channel, 
                    kernel_size=3,
                    stride=stride, 
                    padding=1, 
                    bias=False), 
          nn.BatchNorm2d(out_channel))
    
    layer.append(block(self.in_channel, out_channel, stride, conv))
    self.in_channel = out_channel

    for _ in range(num_layers - 1):
      layer.append(block(self.in_channel, out_channel))

    return nn.Sequential(*layer)
    
  def forward(self, x):
    out = self.conv(x)
    out = self.bn(out)
    out = self.relu(out)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.avg_pool(out)
    out = out.view(out.size(0), -1)
    out = self.fc(out)
    return out

# %%
transform = transforms.Compose([transforms.Pad(4),transforms.RandomHorizontalFlip(),transforms.RandomCrop(32),transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
test_transform  = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,0.5,0.5),std=(0.5,0.5,0.5))])

train_dataset = torchvision.datasets.CIFAR10(root='../../data/', train=True,transform=transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(root='../../data/', train=False,transform=test_transform)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size=100, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../../data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ../../data/cifar-10-python.tar.gz to ../../data/

# %%
depth = 3
epochs = 40
batch_size = 128
base_lr = 0.01
lr_decay = 0.1
milestones = '[80, 120]'
device = "cuda"
num_workers = 3

model = ResNet(block,[10,10,10]).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=base_lr)
# scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=lr_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=lr_decay)

# %%
for epoch in range(epochs):
  for i, (images, labels) in enumerate(train_loader):
    images = images.to(device)
    labels = labels.to(device)
    outputs = model(images)
    loss = criterion(outputs, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if (i+1) % 100 == 0:
      print ("Epoch {}, Step {} Loss: {:.4f}".format(epoch+1, i+1, loss.item()))   
  scheduler.step()
# Out:
# Epoch 1, Step 100 Loss: 1.9018
# Epoch 1, Step 200 Loss: 1.7809
# Epoch 1, Step 300 Loss: 1.4379
# Epoch 1, Step 400 Loss: 1.5117
# Epoch 1, Step 500 Loss: 1.3800
# Epoch 2, Step 100 Loss: 1.2779
# Epoch 2, Step 200 Loss: 1.0572
# Epoch 2, Step 300 Loss: 1.2797
# Epoch 2, Step 400 Loss: 1.1540
# Epoch 2, Step 500 Loss: 1.2174
# Epoch 3, Step 100 Loss: 0.9010
# Epoch 3, Step 200 Loss: 1.0845
# Epoch 3, Step 300 Loss: 1.0221
# Epoch 3, Step 400 Loss: 0.9947
# Epoch 3, Step 500 Loss: 0.9971
# Epoch 4, Step 100 Loss: 0.8517
# Epoch 4, Step 200 Loss: 0.9917
# Epoch 4, Step 300 Loss: 0.8789
# Epoch 4, Step 400 Loss: 1.0005
# Epoch 4, Step 500 Loss: 0.7615
# Epoch 5, Step 100 Loss: 0.8970
# Epoch 5, Step 200 Loss: 0.7268
# Epoch 5, Step 300 Loss: 0.7909
# Epoch 5, Step 400 Loss: 0.6040
# Epoch 5, Step 500 Loss: 0.9037
# Epoch 6, Step 100 Loss: 0.8072
# Epoch 6, Step 200 Loss: 0.7213
# Epoch 6, Step 300 Loss: 0.7595
# Epoch 6, Step 400 Loss: 0.6179
# Epoch 6, Step 500 Loss: 0.5534
# Epoch 7, Step 100 Loss: 0.7832
# Epoch 7, Step 200 Loss: 0.7528
# Epoch 7, Step 300 Loss: 0.6215
# Epoch 7, Step 400 Loss: 0.7706
# Epoch 7, Step 500 Loss: 0.5970
# Epoch 8, Step 100 Loss: 0.5691
# Epoch 8, Step 200 Loss: 0.6278
# Epoch 8, Step 300 Loss: 0.6522
# Epoch 8, Step 400 Loss: 0.5285
# Epoch 8, Step 500 Loss: 0.6308
# Epoch 9, Step 100 Loss: 0.4333
# Epoch 9, Step 200 Loss: 0.7107
# Epoch 9, Step 300 Loss: 0.4990
# Epoch 9, Step 400 Loss: 0.4871
# Epoch 9, Step 500 Loss: 0.5327
# Epoch 10, Step 100 Loss: 0.6023
# Epoch 10, Step 200 Loss: 0.6488
# Epoch 10, Step 300 Loss: 0.5926
# Epoch 10, Step 400 Loss: 0.4848
# Epoch 10, Step 500 Loss: 0.8996
# Epoch 11, Step 100 Loss: 0.4020
# Epoch 11, Step 200 Loss: 0.2862
# Epoch 11, Step 300 Loss: 0.2645
# Epoch 11, Step 400 Loss: 0.3930
# Epoch 11, Step 500 Loss: 0.6028
# Epoch 12, Step 100 Loss: 0.4564
# Epoch 12, Step 200 Loss: 0.2992
# Epoch 12, Step 300 Loss: 0.3005
# Epoch 12, Step 400 Loss: 0.3243
# Epoch 12, Step 500 Loss: 0.3866
# Epoch 13, Step 100 Loss: 0.3430
# Epoch 13, Step 200 Loss: 0.3859
# Epoch 13, Step 300 Loss: 0.2167
# Epoch 13, Step 400 Loss: 0.3523
# Epoch 13, Step 500 Loss: 0.5070
# Epoch 14, Step 100 Loss: 0.3319
# Epoch 14, Step 200 Loss: 0.3548
# Epoch 14, Step 300 Loss: 0.4905
# Epoch 14, Step 400 Loss: 0.3533
# Epoch 14, Step 500 Loss: 0.3458
# Epoch 15, Step 100 Loss: 0.3225
# Epoch 15, Step 200 Loss: 0.3608
# Epoch 15, Step 300 Loss: 0.3867
# Epoch 15, Step 400 Loss: 0.3910
# Epoch 15, Step 500 Loss: 0.3504
# Epoch 16, Step 100 Loss: 0.2803
# Epoch 16, Step 200 Loss: 0.2540
# Epoch 16, Step 300 Loss: 0.2480
# Epoch 16, Step 400 Loss: 0.3380
# Epoch 16, Step 500 Loss: 0.2824
# Epoch 17, Step 100 Loss: 0.3959
# Epoch 17, Step 200 Loss: 0.2075
# Epoch 17, Step 300 Loss: 0.3699
# Epoch 17, Step 400 Loss: 0.3211
# Epoch 17, Step 500 Loss: 0.2773
# Epoch 18, Step 100 Loss: 0.2768
# Epoch 18, Step 200 Loss: 0.2054
# Epoch 18, Step 300 Loss: 0.2017
# Epoch 18, Step 400 Loss: 0.5982
# Epoch 18, Step 500 Loss: 0.3356
# Epoch 19, Step 100 Loss: 0.2427
# Epoch 19, Step 200 Loss: 0.1760
# Epoch 19, Step 300 Loss: 0.2309
# Epoch 19, Step 400 Loss: 0.3800
# Epoch 19, Step 500 Loss: 0.3400
# Epoch 20, Step 100 Loss: 0.2674
# Epoch 20, Step 200 Loss: 0.2648
# Epoch 20, Step 300 Loss: 0.3510
# Epoch 20, Step 400 Loss: 0.2854
# Epoch 20, Step 500 Loss: 0.2310
# Epoch 21, Step 100 Loss: 0.3595
# Epoch 21, Step 200 Loss: 0.2334
# Epoch 21, Step 300 Loss: 0.2589
# Epoch 21, Step 400 Loss: 0.2443
# Epoch 21, Step 500 Loss: 0.3060
# Epoch 22, Step 100 Loss: 0.4069
# Epoch 22, Step 200 Loss: 0.1756
# Epoch 22, Step 300 Loss: 0.3055
# Epoch 22, Step 400 Loss: 0.2723
# Epoch 22, Step 500 Loss: 0.2735
# Epoch 23, Step 100 Loss: 0.2449
# Epoch 23, Step 200 Loss: 0.2940
# Epoch 23, Step 300 Loss: 0.2088
# Epoch 23, Step 400 Loss: 0.2433
# Epoch 23, Step 500 Loss: 0.2363
# Epoch 24, Step 100 Loss: 0.3099
# Epoch 24, Step 200 Loss: 0.2565
# Epoch 24, Step 300 Loss: 0.1917
# Epoch 24, Step 400 Loss: 0.1584
# Epoch 24, Step 500 Loss: 0.1790
# Epoch 25, Step 100 Loss: 0.2028
# Epoch 25, Step 200 Loss: 0.2285
# Epoch 25, Step 300 Loss: 0.2279
# Epoch 25, Step 400 Loss: 0.1930
# Epoch 25, Step 500 Loss: 0.2492
# Epoch 26, Step 100 Loss: 0.2674
# Epoch 26, Step 200 Loss: 0.2305
# Epoch 26, Step 300 Loss: 0.1217
# Epoch 26, Step 400 Loss: 0.3111
# Epoch 26, Step 500 Loss: 0.2057
# Epoch 27, Step 100 Loss: 0.2355
# Epoch 27, Step 200 Loss: 0.1968
# Epoch 27, Step 300 Loss: 0.1161
# Epoch 27, Step 400 Loss: 0.1196
# Epoch 27, Step 500 Loss: 0.2154
# Epoch 28, Step 100 Loss: 0.2815
# Epoch 28, Step 200 Loss: 0.1525
# Epoch 28, Step 300 Loss: 0.2111
# Epoch 28, Step 400 Loss: 0.2275
# Epoch 28, Step 500 Loss: 0.2304
# Epoch 29, Step 100 Loss: 0.2013
# Epoch 29, Step 200 Loss: 0.2759
# Epoch 29, Step 300 Loss: 0.2212
# Epoch 29, Step 400 Loss: 0.1910
# Epoch 29, Step 500 Loss: 0.2112
# Epoch 30, Step 100 Loss: 0.2186
# Epoch 30, Step 200 Loss: 0.2538
# Epoch 30, Step 300 Loss: 0.2790
# Epoch 30, Step 400 Loss: 0.1835
# Epoch 30, Step 500 Loss: 0.1396
# Epoch 31, Step 100 Loss: 0.1802
# Epoch 31, Step 200 Loss: 0.1414
# Epoch 31, Step 300 Loss: 0.2228
# Epoch 31, Step 400 Loss: 0.1251
# Epoch 31, Step 500 Loss: 0.1733
# Epoch 32, Step 100 Loss: 0.1572
# Epoch 32, Step 200 Loss: 0.1565
# Epoch 32, Step 300 Loss: 0.2068
# Epoch 32, Step 400 Loss: 0.2023
# Epoch 32, Step 500 Loss: 0.2243
# Epoch 33, Step 100 Loss: 0.2501
# Epoch 33, Step 200 Loss: 0.1438
# Epoch 33, Step 300 Loss: 0.1897
# Epoch 33, Step 400 Loss: 0.2624
# Epoch 33, Step 500 Loss: 0.3065
# Epoch 34, Step 100 Loss: 0.1804
# Epoch 34, Step 200 Loss: 0.1556
# Epoch 34, Step 300 Loss: 0.2700
# Epoch 34, Step 400 Loss: 0.2319
# Epoch 34, Step 500 Loss: 0.2927
# Epoch 35, Step 100 Loss: 0.1904
# Epoch 35, Step 200 Loss: 0.2301
# Epoch 35, Step 300 Loss: 0.1616
# Epoch 35, Step 400 Loss: 0.1805
# Epoch 35, Step 500 Loss: 0.3276
# Epoch 36, Step 100 Loss: 0.2845
# Epoch 36, Step 200 Loss: 0.1640
# Epoch 36, Step 300 Loss: 0.1865
# Epoch 36, Step 400 Loss: 0.1215
# Epoch 36, Step 500 Loss: 0.2624
# Epoch 37, Step 100 Loss: 0.2116
# Epoch 37, Step 200 Loss: 0.2024
# Epoch 37, Step 300 Loss: 0.1434
# Epoch 37, Step 400 Loss: 0.2331
# Epoch 37, Step 500 Loss: 0.1800
# Epoch 38, Step 100 Loss: 0.0715
# Epoch 38, Step 200 Loss: 0.2876
# Epoch 38, Step 300 Loss: 0.2127
# Epoch 38, Step 400 Loss: 0.2498
# Epoch 38, Step 500 Loss: 0.3860
# Epoch 39, Step 100 Loss: 0.2783
# Epoch 39, Step 200 Loss: 0.1839
# Epoch 39, Step 300 Loss: 0.1674
# Epoch 39, Step 400 Loss: 0.1714
# Epoch 39, Step 500 Loss: 0.2334
# Epoch 40, Step 100 Loss: 0.2472
# Epoch 40, Step 200 Loss: 0.1445
# Epoch 40, Step 300 Loss: 0.2502
# Epoch 40, Step 400 Loss: 0.1826
# Epoch 40, Step 500 Loss: 0.2910

# %%
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Accuracy ( test images ) : {} %'.format(100 * correct / total))
# Out:
# Accuracy ( test images ) : 81.2 %
